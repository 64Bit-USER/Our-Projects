# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
df = pd.read_excel('NIFTY50stocks.xlsx')
df
# Out:
#            DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO    TECHM  RELIANCE  \
# 0    2010-01-11     591.90  423.70  3792.50    6737.95   735.60   1093.20
# 1    2010-01-12     613.55  414.70  3781.90    5443.70   671.15    988.80
# 2    2010-02-11     599.05  433.85  3818.70    6735.25   724.55   1074.85
# 3    2010-02-12     622.75  426.05  3784.20    5368.40   676.35   1011.15
# 4    2010-03-11     609.60  434.70  3833.05    6858.65   732.50   1065.30
# ...         ...        ...     ...      ...        ...      ...       ...
# 2721 2021-12-04     851.55  432.60  1510.45    1121.70  1039.85   1911.15
# 2722 2021-12-05    1179.15  507.60  1454.95    6388.85   962.35   1913.15
# 2723 2021-12-07    1226.95  525.85  1719.85    7093.75  1056.60   2084.10
# 2724 2021-12-08    1435.35  605.85  1823.60    7468.70  1386.55   2110.50
# 2725 2021-12-10    1329.10  659.10  2492.60    7250.15  1374.45   2667.80
#
#       SHREECEM  SUNPHARMA  TATAMOTORS  ...  BAJAJFINSERV  BAJAJFINANCE  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            DATE  TATASTEEL   WIPRO    TITAN  ULTRACEMO    TECHM  RELIANCE  \
# 0    2010-01-11     591.90  423.70  3792.50    6737.95   735.60   1093.20
# 1    2010-01-12     613.55  414.70  3781.90    5443.70   671.15    988.80
# 2    2010-02-11     599.05  433.85  3818.70    6735.25   724.55   1074.85
# 3    2010-02-12     622.75  426.05  3784.20    5368.40   676.35   1011.15
# 4    2010-03-11     609.60  434.70  3833.05    6858.65   732.50   1065.30
# ...         ...        ...     ...      ...        ...      ...       ...
# 2721 2021-12-04     851.55  432.60  1510.45    1121.70  1039.85   1911.15
# 2722 2021-12-05    1179.15  507.60  1454.95    6388.85   962.35   1913.15
# 2723 2021-12-07    1226.95  525.85  1719.85    7093.75  1056.60   2084.10
# 2724 2021-12-08    1435.35  605.85  1823.60    7468.70  1386.55   2110.50
# 2725 2021-12-10    1329.10  659.10  2492.60    7250.15  1374.45   2667.80
#
# ...

# %%
df.shape
# Out:
# (2726, 47)

# %%
#All the columns
df.columns
# Out:
# Index(['DATE', 'TATASTEEL', 'WIPRO', 'TITAN', 'ULTRACEMO', 'TECHM', 'RELIANCE',
#        'SHREECEM', 'SUNPHARMA', 'TATAMOTORS', 'TCS', 'SBIN', 'NESTLEIND',
#        'NTPC', 'M&M', 'MARUTI', 'ONGC', 'POWERGRID', 'JSWSTEEL', 'KOTAKBANK',
#        'LT', 'ICICIBANK', 'INDUSBANK', 'IOC', 'ITC', 'HINDALCO', 'HINDUNILVR',
#        'HCL TECH', 'HDFC BANK', 'HDFC', 'DRREDDYS', 'EICHERMOTOR', 'GRASIM',
#        'CIPLA', 'COALINDIA', 'BPCL', 'BRITANNIA', 'BAJAJFINSERV',
#        'BAJAJFINANCE', 'BHARTIARTL', 'AXISBANK', 'BAJAJ-AUTO', 'ASIANPAINT',
#        'UPL', 'INFY', 'HEROMOTOCO', 'ADANIPORTS'],
#       dtype='object')

# %%
df.loc[:20, ['UPL', 'INFY', 'HEROMOTOCO', 'ADANIPORTS']]
# Out:
#     UPL INFY HEROMOTOCO ADANIPORTS
# 0   nil  nil        nil        nil
# 1   nil  nil        nil        nil
# 2   nil  nil        nil        nil
# 3   nil  nil        nil        nil
# 4   nil  nil        nil        nil
# 5   nil  nil        nil        nil
# 6   nil  nil        nil        nil
# 7   nil  nil        nil        nil
# 8   nil  nil        nil        nil
# 9   nil  nil        nil        nil
# 10  nil  nil        nil        nil
# 11  nil  nil        nil        nil
# 12  nil  nil        nil        nil
# 13  nil  nil        nil        nil
# 14  nil  nil        nil        nil
# 15  nil  nil        nil        nil
# 16  nil  nil        nil        nil
# 17  nil  nil        nil        nil
# 18  nil  nil        nil        nil
# 19  nil  nil        nil        nil
# 20  nil  nil        nil        nil
