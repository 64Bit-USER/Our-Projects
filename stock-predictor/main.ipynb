# %%
import math
import datetime
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

# %% [markdown]
# Importing style of plot

# %%
plt.style.use('fivethirtyeight')

# %%
#Get the stock dataframe
today_date = datetime.datetime.now()
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end=today_date)
#Show the data
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2012-01-03   14.732143   14.607143   14.621429   14.686786  302220800.0
# 2012-01-04   14.810000   14.617143   14.642857   14.765714  260022000.0
# 2012-01-05   14.948214   14.738214   14.819643   14.929643  271269600.0
# 2012-01-06   15.098214   14.972143   14.991786   15.085714  318292800.0
# 2012-01-09   15.276786   15.048214   15.196429   15.061786  394024400.0
# ...                ...         ...         ...         ...          ...
# 2021-10-13  141.399994  139.199997  141.240005  140.910004   78762700.0
# 2021-10-14  143.880005  141.509995  142.110001  143.759995   69907100.0
# 2021-10-15  144.899994  143.509995  143.770004  144.839996   67885200.0
# 2021-10-18  146.839996  143.160004  143.449997  146.550003   85268800.0
# 2021-10-19  147.889999  146.550003  147.009995  147.705002   13180796.0
#
#              Adj Close
# Date
# 2012-01-03   12.610316
# 2012-01-04   12.678084
# 2012-01-05   12.818836
# 2012-01-06   12.952841
# 2012-01-09   12.932295
# ...                ...
# 2021-10-13  140.910004
# 2021-10-14  143.759995
# 2021-10-15  144.839996
# 2021-10-18  146.550003
# 2021-10-19  147.705002
#
# [2466 rows x 6 columns]

# %%
df.shape
# Out:
# (2466, 6)

# %%
#Visualize the Closing price
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.xlabel('Date', fontsize=18)
plt.ylabel('USD $', fontsize=18)
plt.show()
